# %% [markdown]
# # LetsGrowMore Data Science Internship

# %% [markdown]
# # Task-2 Image to Pencil Sketch with Python

# %% [markdown]
# # Name- Ujwal Nafade

# %%
pip install opencv-contrib-python-headless
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("C:/Users/91703/Downloads/Ganesh Chaturthi - ways to involve kids in celebration and rituals_.jpg")

# %%
# Read the image in RGB format
img_rbg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(img_rbg)
plt.title("Colored Image")
plt.axis("off")
# Out:
# (-0.5, 735.5, 1330.5, -0.5)

# %%
# Covert the original image to grayscale image
grayimage=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10,6))
plt.imshow(grayimage, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
# Out:
# (-0.5, 735.5, 1330.5, -0.5)

# %%
# Inverting image
inv_img=255-grayimage
plt.figure(figsize=(10,6))
plt.imshow(inv_img,cmap='gray')
plt.title("Inverted Image")
plt.axis("off")
# Out:
# (-0.5, 735.5, 1330.5, -0.5)

# %%
# Blur image
blur=cv2.GaussianBlur(inv_img,(21,21),0)
plt.figure(figsize=(10,6))
plt.imshow(blur,cmap='gray')
plt.title('Smoothen Image')
plt.axis('off')
# Out:
# (-0.5, 735.5, 1330.5, -0.5)

# %% [markdown]
# # Convert image to pencil sketch

# %%
skh=cv2.divide(grayimage,255-blur,scale=255)
plt.figure(figsize=(10,6))
plt.imshow(skh,cmap='gray')
plt.title("Final Sketch")
plt.axis('off')
# Out:
# (-0.5, 735.5, 1330.5, -0.5)
